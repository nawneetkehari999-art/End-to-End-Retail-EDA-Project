# %%
# importing important Libraries

import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
import datetime

# %% [markdown]
# ### 1. Import dataset

# %%
df = pd.read_csv("../Superstore_Management_System2.csv")
df
# Out:
#      OrderId  Order Date   Ship Date Customer ID      Customer Name  \
# 0    ODR1000  12-01-2026  17-01-2026     CUST503     Jennifer Scott
# 1    ODR1001  15-07-2025  21-07-2025     CUST640      Stacey Nguyen
# 2    ODR1002  01-03-2025  04-03-2025     CUST492       James Rivera
# 3    ODR1003  20-07-2025  25-07-2025     CUST400  Nicholas Thompson
# 4    ODR1004  28-12-2025  31-12-2025     CUST668        Paul Thomas
# ..       ...         ...         ...         ...                ...
# 995  ODR1995  11-08-2025  13-08-2025     CUST916     Elizabeth Bell
# 996  ODR1996  25-12-2025  28-12-2025     CUST511       Frances Reed
# 997  ODR1997  04-12-2024  06-12-2024     CUST585       Danny Graham
# 998  ODR1998  08-07-2024  12-07-2024     CUST544        Joe Stevens
# 999  ODR1999  08-07-2024  13-07-2024     CUST970    Jeremy Richards
#
#     Customer Segment Product ID Product Name         Category Region  ...  \
# 0        Home Office   PROD7985      Monitor      Electronics  South  ...
# ...

# %% [markdown]
# ## Basic Analysis
#
# ### 2. Finding Head

# %%
df.head()
# Out:
#    OrderId  Order Date   Ship Date Customer ID      Customer Name  \
# 0  ODR1000  12-01-2026  17-01-2026     CUST503     Jennifer Scott
# 1  ODR1001  15-07-2025  21-07-2025     CUST640      Stacey Nguyen
# 2  ODR1002  01-03-2025  04-03-2025     CUST492       James Rivera
# 3  ODR1003  20-07-2025  25-07-2025     CUST400  Nicholas Thompson
# 4  ODR1004  28-12-2025  31-12-2025     CUST668        Paul Thomas
#
#   Customer Segment Product ID Product Name         Category Region  ...  \
# 0      Home Office   PROD7985      Monitor      Electronics  South  ...
# 1         Consumer   PROD7562     Notebook  Office Supplies  South  ...
# 2        Corporate   PROD1771   Juice Pack          Grocery   East  ...
# 3         Consumer   PROD6803     Keyboard      Electronics   East  ...
# 4        Corporate   PROD7613  Cooking Oil          Grocery   West  ...
#
#   Sales Amount Cost Price    Profit  Payment Mode  Delivery Status  \
# ...

# %% [markdown]
# ### ing Tail

# %%
df.tail()
# Out:
#      OrderId  Order Date   Ship Date Customer ID    Customer Name  \
# 995  ODR1995  11-08-2025  13-08-2025     CUST916   Elizabeth Bell
# 996  ODR1996  25-12-2025  28-12-2025     CUST511     Frances Reed
# 997  ODR1997  04-12-2024  06-12-2024     CUST585     Danny Graham
# 998  ODR1998  08-07-2024  12-07-2024     CUST544      Joe Stevens
# 999  ODR1999  08-07-2024  13-07-2024     CUST970  Jeremy Richards
#
#     Customer Segment Product ID Product Name         Category Region  ...  \
# 995        Corporate   PROD3365        Sugar          Grocery  South  ...
# 996      Home Office   PROD7781     Keyboard      Electronics  North  ...
# 997      Home Office   PROD5324  Cooking Oil          Grocery  North  ...
# 998         Consumer   PROD8037       Laptop      Electronics  North  ...
# 999        Corporate   PROD1313     Notebook  Office Supplies  South  ...
#
#     Sales Amount Cost Price   Profit  Payment Mode  Delivery Status  \
# ...

# %% [markdown]
# ### 4. Finding Type

# %%
f'Data Type is: {type(df)}'
# Out:
# "Data Type is: <class 'pandas.core.frame.DataFrame'>"

# %% [markdown]
# ### 5. Finding Data Type For Each Columns.

# %%
df.dtypes
# Out:
# OrderId              object
# Order Date           object
# Ship Date            object
# Customer ID          object
# Customer Name        object
# Customer Segment     object
# Product ID           object
# Product Name         object
# Category             object
# Region               object
# State                object
# City                 object
# Quantity              int64
# Unit Price            int64
# Discount(%)           int64
# Sales Amount        float64
# Cost Price          float64
# Profit              float64
# Payment Mode         object
# Delivery Status      object
# Supplier Name        object
# Supplier Email       object
# Stock Left            int64
# Auto Reorder         object
# Reorder Quantity      int64
# dtype: object

# %% [markdown]
# ### 6. Finding Random Sample From Dataset

# %%
df.sample(3)
# Out:
#      OrderId  Order Date   Ship Date Customer ID    Customer Name  \
# 317  ODR1317  29-12-2025  31-12-2025     CUST727   Jeffery Howard
# 339  ODR1339  22-01-2025  23-01-2025     CUST820      Brett Allen
# 253  ODR1253  02-03-2025  05-03-2025     CUST349  Michelle Fuller
#
#     Customer Segment Product ID Product Name         Category Region  ...  \
# 317         Consumer   PROD9348      Stapler  Office Supplies   West  ...
# 339      Home Office   PROD8761         Sofa        Furniture   West  ...
# 253        Corporate   PROD4761      Stapler  Office Supplies   East  ...
#
#     Sales Amount Cost Price   Profit  Payment Mode  Delivery Status  \
# 317      27548.1   22485.83  5062.27   Net Banking        Delivered
# 339       1089.6     966.77   122.83   Credit Card          Pending
# 253      15150.0    9457.09  5692.91   Net Banking        Cancelled
#
#                 Supplier Name          Supplier Email  Stock Left  \
# ...

# %% [markdown]
# ### 7. Finding Summary of Dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   OrderId           1000 non-null   object
#  1   Order Date        1000 non-null   object
#  2   Ship Date         1000 non-null   object
#  3   Customer ID       1000 non-null   object
#  4   Customer Name     1000 non-null   object
#  5   Customer Segment  1000 non-null   object
#  6   Product ID        1000 non-null   object
#  7   Product Name      1000 non-null   object
#  8   Category          1000 non-null   object
#  9   Region            1000 non-null   object
#  10  State             1000 non-null   object
#  11  City              1000 non-null   object
#  12  Quantity          1000 non-null   int64
#  13  Unit Price        1000 non-null   int64
#  14  Discount(%)       1000 non-null   int64
#  15  Sales Amount      1000 non-null   float64
# ...

# %% [markdown]
# ### 8. Finding All Columns Name

# %%
df.columns
# Out:
# Index(['OrderId', 'Order Date', 'Ship Date', 'Customer ID', 'Customer Name',
#        'Customer Segment', 'Product ID', 'Product Name', 'Category', 'Region',
#        'State', 'City', 'Quantity', 'Unit Price', 'Discount(%)',
#        'Sales Amount', 'Cost Price', 'Profit', 'Payment Mode',
#        'Delivery Status', 'Supplier Name', 'Supplier Email', 'Stock Left',
#        'Auto Reorder', 'Reorder Quantity'],
#       dtype='object')

# %% [markdown]
# ### 9. Find All Data

# %%
# pd.set_option('display.max_rows',None)
df
# Out:
#      OrderId  Order Date   Ship Date Customer ID      Customer Name  \
# 0    ODR1000  12-01-2026  17-01-2026     CUST503     Jennifer Scott
# 1    ODR1001  15-07-2025  21-07-2025     CUST640      Stacey Nguyen
# 2    ODR1002  01-03-2025  04-03-2025     CUST492       James Rivera
# 3    ODR1003  20-07-2025  25-07-2025     CUST400  Nicholas Thompson
# 4    ODR1004  28-12-2025  31-12-2025     CUST668        Paul Thomas
# ..       ...         ...         ...         ...                ...
# 995  ODR1995  11-08-2025  13-08-2025     CUST916     Elizabeth Bell
# 996  ODR1996  25-12-2025  28-12-2025     CUST511       Frances Reed
# 997  ODR1997  04-12-2024  06-12-2024     CUST585       Danny Graham
# 998  ODR1998  08-07-2024  12-07-2024     CUST544        Joe Stevens
# 999  ODR1999  08-07-2024  13-07-2024     CUST970    Jeremy Richards
#
#     Customer Segment Product ID Product Name         Category Region  ...  \
# 0        Home Office   PROD7985      Monitor      Electronics  South  ...
# ...

# %% [markdown]
# ### 10. Findling Out the Shape Of Dataset

# %%
f'Thare are totla rows and columns is:{df.shape}'
# Out:
# 'Thare are totla rows and columns is:(1000, 25)'

# %% [markdown]
# ### 11. Finding Out Discription of Dataset

# %%
df.describe(include='object')
# Out:
#         OrderId  Order Date   Ship Date Customer ID      Customer Name  \
# count      1000        1000        1000        1000               1000
# unique     1000         537         546         617                991
# top     ODR1999  26-05-2024  19-06-2024     CUST780  Stephanie Jackson
# freq          1           8           6           5                  2
#
#        Customer Segment Product ID Product Name Category Region     State  \
# count              1000       1000         1000     1000   1000      1000
# unique                3        956           20        4      4        50
# top            Consumer   PROD9929  Cooking Oil  Grocery   East  Kentucky
# freq                341          3           61      283    261        33
#
#                City Payment Mode Delivery Status Supplier Name  \
# count          1000         1000            1000          1000
# unique          949            4               4           971
# ...

# %% [markdown]
# ### 12. finding Out Null Values

# %%
df.isnull().sum()
# Out:
# OrderId             0
# Order Date          0
# Ship Date           0
# Customer ID         0
# Customer Name       0
# Customer Segment    0
# Product ID          0
# Product Name        0
# Category            0
# Region              0
# State               0
# City                0
# Quantity            0
# Unit Price          0
# Discount(%)         0
# Sales Amount        0
# Cost Price          0
# Profit              0
# Payment Mode        0
# Delivery Status     0
# Supplier Name       0
# Supplier Email      0
# Stock Left          0
# Auto Reorder        0
# Reorder Quantity    0
# dtype: int64
